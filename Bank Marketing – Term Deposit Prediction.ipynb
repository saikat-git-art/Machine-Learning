# %%
'''
Assignment 2: Bank Marketing – Term Deposit Prediction
Dataset: Bank Marketing
Link: https://raw.githubusercontent.com/selva86/datasets/master/BankMarketing.csv
Task:
 Predict if a customer will subscribe to a term deposit.
 Handle missing values.
 Encode categorical variables using LabelEncoder.
 Apply StandardScaler.
 Train logistic regression & calculate Confusion Matrix + F1-score.
'''

# %%
import pandas as pd

# %%
df = pd.read_csv('bank-additional-full.csv',sep=';')
print("Number of rows:", df.shape[0], "Number of columns:", df.shape[1])   ## load the dataset
# Out:
# Number of rows: 41188 Number of columns: 21

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df.isnull().sum()  ## check null value is present or not
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.columns  ## print all columns of this dataset
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df['duration'].values
# Out:
# array([261, 149, 226, ..., 189, 442, 239], dtype=int64)

# %%
df1 = df.drop(['duration'],axis=1)  ## this is not to be need . so drop this column

# %%
df1  ## print new dataset
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
import numpy as np

# %%
df1['job'].values
# Out:
# array(['housemaid', 'services', 'services', ..., 'retired', 'technician',
#        'retired'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()  # create object of label encoder

# %%
df1[['job','marital','default','housing','loan','contact','poutcome']] = df1[['job','marital','default','housing','loan','contact','poutcome']] .apply(le.fit_transform)

# %%
df1
# Out:
#        age  job  marital            education  default  housing  loan  \
# 0       56    3        1             basic.4y        0        0     0
# 1       57    7        1          high.school        1        0     0
# 2       37    7        1          high.school        0        2     0
# 3       40    0        1             basic.6y        0        0     0
# 4       56    7        1          high.school        0        0     2
# ...    ...  ...      ...                  ...      ...      ...   ...
# 41183   73    5        1  professional.course        0        2     0
# 41184   46    1        1  professional.course        0        0     0
# 41185   56    5        1    university.degree        0        2     0
# 41186   44    9        1  professional.course        0        0     0
# 41187   74    5        1  professional.course        0        2     0
#
#        contact month day_of_week  campaign  pdays  previous  poutcome  \
# ...

# %%
df1['education'].sample(10)
# Out:
# 7037     professional.course
# 30919            high.school
# 16754               basic.6y
# 35915               basic.9y
# 14298               basic.9y
# 34176               basic.6y
# 16234    professional.course
# 12682               basic.9y
# 5156       university.degree
# 38675            high.school
# Name: education, dtype: object

# %%
df1['month'].sample(10)
# Out:
# 21184    aug
# 30331    apr
# 6362     may
# 3211     may
# 15184    jul
# 7724     may
# 3628     may
# 22974    aug
# 14241    jul
# 28473    apr
# Name: month, dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=[['illiterate','basic.4y','basic.6y','basic.9y','high.school','university.degree','professional.course','unknown'],['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec'],['sun','mon','tue','wed','thu','fri','sat']])

# %%
import sys
try:
    oe.fit(df1[['education','month','day_of_week']])
except Exception:
    print(sys.exc_info())

# %%
oe.fit(df1[['education','month','day_of_week']])
# Out:
# OrdinalEncoder(categories=[['illiterate', 'basic.4y', 'basic.6y', 'basic.9y',
#                             'high.school', 'university.degree',
#                             'professional.course', 'unknown'],
#                            ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul',
#                             'aug', 'sep', 'oct', 'nov', 'dec'],
#                            ['sun', 'mon', 'tue', 'wed', 'thu', 'fri', 'sat']])

# %%
df1[['education','month','day_of_week']] = oe.transform(df1[['education','month','day_of_week']])  ## transform this value into order

# %%
df1
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       56    3        1        1.0        0        0     0        1    4.0
# 1       57    7        1        4.0        1        0     0        1    4.0
# 2       37    7        1        4.0        0        2     0        1    4.0
# 3       40    0        1        2.0        0        0     0        1    4.0
# 4       56    7        1        4.0        0        0     2        1    4.0
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41183   73    5        1        6.0        0        2     0        0   10.0
# 41184   46    1        1        6.0        0        0     0        0   10.0
# 41185   56    5        1        5.0        0        2     0        0   10.0
# 41186   44    9        1        6.0        0        0     0        0   10.0
# 41187   74    5        1        6.0        0        2     0        0   10.0
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df1[['age','pdays','cons.conf.idx','cons.price.idx','nr.employed']])
# Out:
# StandardScaler()

# %%
df1[['age','pdays','cons.conf.idx','cons.price.idx','nr.employed']] = scaler.transform(df1[['age','pdays','cons.conf.idx','cons.price.idx','nr.employed']])  ## scalling of this column

# %%
df1
# Out:
#             age  job  marital  education  default  housing  loan  contact  \
# 0      1.533034    3        1        1.0        0        0     0        1
# 1      1.628993    7        1        4.0        1        0     0        1
# 2     -0.290186    7        1        4.0        0        2     0        1
# 3     -0.002309    0        1        2.0        0        0     0        1
# 4      1.533034    7        1        4.0        0        0     2        1
# ...         ...  ...      ...        ...      ...      ...   ...      ...
# 41183  3.164336    5        1        6.0        0        2     0        0
# 41184  0.573445    1        1        6.0        0        0     0        0
# 41185  1.533034    5        1        5.0        0        2     0        0
# 41186  0.381527    9        1        6.0        0        0     0        0
# 41187  3.260295    5        1        6.0        0        2     0        0
#
#        month  day_of_week  campaign     pdays  previous  poutcome  \
# ...

# %%
le.fit(df1['y'])
# Out:
# LabelEncoder()

# %%
df1['y'] = le.transform(df1['y'])

# %%
df1
# Out:
#             age  job  marital  education  default  housing  loan  contact  \
# 0      1.533034    3        1        1.0        0        0     0        1
# 1      1.628993    7        1        4.0        1        0     0        1
# 2     -0.290186    7        1        4.0        0        2     0        1
# 3     -0.002309    0        1        2.0        0        0     0        1
# 4      1.533034    7        1        4.0        0        0     2        1
# ...         ...  ...      ...        ...      ...      ...   ...      ...
# 41183  3.164336    5        1        6.0        0        2     0        0
# 41184  0.573445    1        1        6.0        0        0     0        0
# 41185  1.533034    5        1        5.0        0        2     0        0
# 41186  0.381527    9        1        6.0        0        0     0        0
# 41187  3.260295    5        1        6.0        0        2     0        0
#
#        month  day_of_week  campaign     pdays  previous  poutcome  \
# ...

# %%
df1[['age','pdays','cons.conf.idx','cons.price.idx','euribor3m','nr.employed']].corr()  # check correlation
# Out:
#                      age     pdays  cons.conf.idx  cons.price.idx  euribor3m  \
# age             1.000000 -0.034369       0.129372        0.000857   0.010767
# pdays          -0.034369  1.000000      -0.091342        0.078889   0.296899
# cons.conf.idx   0.129372 -0.091342       1.000000        0.058986   0.277686
# cons.price.idx  0.000857  0.078889       0.058986        1.000000   0.688230
# euribor3m       0.010767  0.296899       0.277686        0.688230   1.000000
# nr.employed    -0.017725  0.372605       0.100513        0.522034   0.945154
#
#                 nr.employed
# age               -0.017725
# pdays              0.372605
# cons.conf.idx      0.100513
# cons.price.idx     0.522034
# euribor3m          0.945154
# nr.employed        1.000000

# %%
from sklearn.model_selection import train_test_split

# %%
x = df1.drop(['y'],axis=1)

# %%
y = df1['y'].values

# %%
x_train , x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\Saikat Maiti\Downloads\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,mean_absolute_error,confusion_matrix,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8992473901432386

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.10075260985676135

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[7220,  105],
#        [ 725,  188]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      7325
#            1       0.64      0.21      0.31       913
#
#     accuracy                           0.90      8238
#    macro avg       0.78      0.60      0.63      8238
# weighted avg       0.88      0.90      0.88      8238
