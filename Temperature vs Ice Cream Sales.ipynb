# %%
'''
5. Temperature vs Ice Cream Sales
Dataset: https://raw.githubusercontent.com/selva86/datasets/master/IceCreamData.csv
Task: Predict ice cream sales based on temperature using Polynomial Regression.

'''

# %%
import pandas as pd
# Out:
# C:\Users\Saikat Maiti\Downloads\Anaconda\Lib\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('Ice Cream Sales - temperatures.csv')

# %%
df
# Out:
#      Temperature  Ice Cream Profits
# 0             39              13.17
# 1             40              11.88
# 2             41              18.82
# 3             42              18.65
# 4             43              17.02
# ..           ...                ...
# 360           99              85.13
# 361           99              87.08
# 362           99              89.29
# 363          101              81.91
# 364          101              85.02
#
# [365 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Temperature          0
# Ice Cream Profits    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Temperature'],df['Ice Cream Profits'])
plt.title('Ice Cream Sales v/s temperatures')
plt.xlabel('Temperature')
plt.ylabel('Ice Cream Profits')
# Out:
# Text(0, 0.5, 'Ice Cream Profits')

# %%
x = df['Temperature'].values

# %%
x1 = x.reshape(-1,1)

# %%
y = df['Ice Cream Profits'].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x1,y,test_size=0.2)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree=1)

# %%
pf.fit(x_train , y_train)
# Out:
# PolynomialFeatures(degree=1)

# %%
x_train_trans = pf.transform(x_train)
x_test_trans = pf.transform(x_test)

# %%
lr.fit(x_train_trans,y_train)
# Out:
# LinearRegression()

# %%
y_pred1 = lr.predict(x_test_trans)

# %%
from sklearn.metrics import r2_score,mean_absolute_error

# %%
r2_score(y_test,y_pred1)
# Out:
# 0.9757392076613213

# %%
mean_absolute_error(y_test,y_pred1)
# Out:
# 1.9122803656842027

# %%
mae = []
for i in range(0,10):
    pf = PolynomialFeatures(degree=i)
    pf.fit(x_train,y_train)
    x_train_trans = pf.transform(x_train)
    x_test_trans = pf.transform(x_test)
    lr.fit(x_train_trans,y_train)
    y_pred2 = lr.predict(x_test_trans)
    m = mean_absolute_error(y_pred2,y_test)
    mae.append(m)

# %%
plt.plot(range(0,10),mae)
